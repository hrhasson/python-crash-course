# %% [markdown]
# ## Exercises
#
# ### written by [Jackie Champagne](https://github.com/jbchampagne/pythontutorials) (UT Austin), adapted by [Hannah Hasson](https://github.com/hrhasson/python-for-high-schoolers) (U of Rochester)
# &nbsp;
#
# This will be a notebook for you to work through the exercises during the workshop. Feel free to work on these at whatever pace you feel works for you, but I encourage you to work together! Edit the title of this notebook with your name because I will ask you to send your final notebook to me at the end of this workshop.
#
# Feel free to google the documentation for numpy, matplotlib, etc.
#
# Don't forget to start by importing any libraries you need.

# %%
# import your libraries here

import numpy as np

import matplotlib.pyplot as plt

#make axes larger on all plots
plt.rc('ytick',labelsize=16)
plt.rc('xtick',labelsize=16)

# %% [markdown]
# ### Day 1
#
# #### Exercise 1
#
#    A. Create an array with 10 evenly spaced values in logspace ranging from 0.1 to 10,000.
#
#    B. Print the following values: The first value in the array, the final value in the array, and the range of 5th-8th values.
#
#    C. Append the numbers 10,001 and 10,002 (as floats) to the array. Make sure you define this!
#
#    D. Divide your new array by 2.
#
#    E. Reshape your array to be 3 x 4 (see the functions before Question 10).
#
#    F. Multiply your array by itself.
#
#    G.  Print out the number of dimensions and the maximum value.

# %%
# your solution here

# %% [markdown]
# ### Day 2

# %% [markdown]
# #### Exercise 1
#
# A. Create a 10x1 array containing the values 4, 0, 6, 5, 11, 14, 12, 14, 5, 16.
#
# B. Create a 10x2 array of zeros.
#
# C. **Write a for loop** that checks for the first array if each number squared is less than 100. If the statement is true, change the corresponding row of your zeros array to equal the number and its square. Hint: you can change the value of the array by stating "zerosarray[i] = [a number, a number squared]".
#
# D. Print out the final version of your zeros array.
#
# Hint: should you loop over the *elements* of the array or the *indices* of the array?

# %%
# your solutions here

# %% [markdown]
# #### Exercise 2
#
#    A. Write a function that takes the variables x, $\mu$ (mu) and $\sigma$ (sigma) and spits out the Gaussian distribution. Yes, there is a function for this in Python, but it's good to do this from scratch! This is the equation:
#
# $$ f(x) = \frac{1}{\sigma \sqrt{2\pi}} \exp{\frac{-(x - \mu)^2}{2\sigma^2}} $$
#
# *Be careful with parentheses!!* (Pi is built into numpy, so call it as np.pi.)
#
#    B. Make a linspace array with 100 points for x between $-10 \le x \le 10$. Call the function three different times for different values of mu and sigma, feeding in the array of x's you just made for all three.
#
#    C. Plot each version, making sure they are differentiated with different colors and/or linestyles and include a legend. Btw, here's a list of the customizations available in matplotlib:
#
#     https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html
#
#     https://matplotlib.org/gallery/color/named_colors.html
#
#    D. Save your figure (see the end of Day 2).
#
# If you have multiple plot statements in a row (multiple lines with plt.plot()), Python will plot all of them on the same figure, unless you write plt.show() after each one. I want these all on one plot, so write plt.show() after all three.

# %%
# your solutions here

# %% [markdown]
# ### Day 3
#
# #### Exercise 1
#
# There is a file in this directory called "histogram_exercise.dat" which consists of of randomly generated samples from a Gaussian distribution with an unknown $\mu$ and $\sigma$. Using what you've learned about fitting data, load up this file using np.genfromtxt, fit a Gaussian curve to the data and plot both the curve and the histogram of the data together. As always, label everything, play with the colors, and choose a judicious bin size.
#
# Hint: if you attempt to call a function from a library or package that hasn't been imported, you will get an error.

# %%
# your solution here

# %% [markdown]
# #### Exercise 2
#
# Create a 1D interpolation along these arrays. Plot both the data (as points) and the interpolation (as a dotted line). Also plot the value of the interpolated function at x=325. What does the function look like to you?

# %%
x = np.array([0., 50., 100., 150., 200., 250., 300., 350., 400., 450., 500])
y = np.array([0., 7.071, 10., 12.247, 14.142, 15.811, 17.321, 18.708, 20., 21.213, 22.361])

# solution here
