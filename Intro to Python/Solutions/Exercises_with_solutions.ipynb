# %% [markdown]
# ## Exercises
#
# ### written by [Jackie Champagne](http://jackiechampagne.com/) (UT Austin), adapted by [Hannah Hasson](https://hrhasson.github.io/) (U of Rochester)
#
# &nbsp;
#
# This will be a notebook for you to work through the exercises during the workshop. Feel free to work on these at whatever pace you feel works for you, but I encourage you to work together! **Edit the title of this notebook with your name** because I will ask you to upload your final notebook to our shared Google drive at the end of this workshop.
#
# &nbsp;
#
# Feel free to look up the documentation for [numpy](https://numpy.org/doc/stable/), [matplotlib](https://matplotlib.org/stable/contents.html), [OpenCV](https://docs.opencv.org/3.4/d7/dbd/group__imgproc.html), etc.
#
# Don't forget to start by importing any libraries you need. I'll give you the classics to start with:

# %%
# import your libraries here

import numpy as np

import matplotlib.pyplot as plt

import cv2 

from scipy import optimize as opt

#make axes larger on all plots
plt.rc('ytick',labelsize=16)
plt.rc('xtick',labelsize=16)

# %% [markdown]
# ### Day 1
#
# #### Exercise 1
#
#    A. Create an array with 10 evenly spaced values ranging from 42 to 350.
#
#    B. Print the following values: The first value in the array, the final value in the array, and a slice of the 5th through the 8th values (think carefully about the indices).
#
#    C. Append the numbers 10,001 and 10,002 (as floats) to the array. Make sure you assign the array to a variable!
#
#    D. Divide your new array by 2.
#
#    E. Reshape your array to be 3 x 4.
#
#    F. Multiply your array by itself.
#
#    G.  Print out the number of dimensions and the maximum value.

# %%
# your solution here

#A.
logarray = np.linspace(42, 350, 10)
print("logarray:", logarray, "\n \n")

#B.
print("first:", logarray[0], "last:", logarray[-1], "5th-8th:", logarray[4:8], "\n \n")

#C. 
appended_logarray = np.append(logarray, [10001., 10002.])
print("appended array:", appended_logarray, "\n \n")

#D. 
divided_array = appended_logarray / 2
appended_logarray /= 2
print("divided array:", divided_array, "\n \n")
print("efficiently divided array:", appended_logarray, "\n \n")

#E. 
reshaped_array = divided_array.reshape(3, 4)
print("3x4 array:", reshaped_array, "\n \n")

#F. 
multiplied_array = reshaped_array**2
multiplied_array_dot = np.dot(reshaped_array, reshaped_array.T)
reshaped_array **= 2
print("multiplied arrays:", multiplied_array, "\n \n", multiplied_array_dot, "\n \n",\
     reshaped_array, "\n" "\n")

#G.
print("n dimensions:", reshaped_array.ndim, "max value:", np.max(reshaped_array))
#note that if you use max(), you will need to flatten the array
#np.max knows what you mean
#np.amax also knows what you mean
# Out:
# logarray: [ 42.          76.22222222 110.44444444 144.66666667 178.88888889
#  213.11111111 247.33333333 281.55555556 315.77777778 350.        ]
#
#
# first: 42.0 last: 350.0 5th-8th: [178.88888889 213.11111111 247.33333333 281.55555556]
#
#
# appended array: [   42.            76.22222222   110.44444444   144.66666667
#    178.88888889   213.11111111   247.33333333   281.55555556
#    315.77777778   350.         10001.         10002.        ]
#
#
# divided array: [  21.           38.11111111   55.22222222   72.33333333   89.44444444
#   106.55555556  123.66666667  140.77777778  157.88888889  175.
#  5000.5        5001.        ]
#
#
# efficiently divided array: [  21.           38.11111111   55.22222222   72.33333333   89.44444444
#   106.55555556  123.66666667  140.77777778  157.88888889  175.
#  5000.5        5001.        ]
#
#
# 3x4 array: [[  21.           38.11111111   55.22222222   72.33333333]
#  [  89.44444444  106.55555556  123.66666667  140.77777778]
#  [ 157.88888889  175.         5000.5        5001.        ]]
#
#
# multiplied arrays: [[4.41000000e+02 1.45245679e+03 3.04949383e+03 5.23211111e+03]
#  [8.00030864e+03 1.13540864e+04 1.52934444e+04 1.98183827e+04]
#  [2.49289012e+04 3.06250000e+04 2.50050002e+07 2.50100010e+07]]
#
#  [[1.01750617e+04 2.29513580e+04 6.47862833e+05]
#  [2.29513580e+04 5.44662222e+04 1.35519434e+06]
#  [6.47862833e+05 1.35519434e+06 5.00705552e+07]]
#
#  [[4.41000000e+02 1.45245679e+03 3.04949383e+03 5.23211111e+03]
#  [8.00030864e+03 1.13540864e+04 1.52934444e+04 1.98183827e+04]
#  [2.49289012e+04 3.06250000e+04 2.50050002e+07 2.50100010e+07]]
#
#
# n dimensions: 2 max value: 25010001.0

# %% [markdown]
# ### Day 2

# %% [markdown]
# #### Exercise 1
#
# A. Create an array containing the values 4, 0, 6, 5, 11, 14, 12, 14, 5, 16.
#
# B. Create a 10x2 array of zeros.
#
# C. Write a for loop that checks if each of the numbers in the first array squared is less than 100. If the statement is true, change that row of your zeros array to equal the number and its square. Hint: you can change the value of an array by stating "zerosarray[i] = [a number, a number squared]".
#
# D. Print out the final version of your zeros array.
#
# Hint: should you loop over the elements of the array or the indices of the array?

# %%
# your solutions here

#A.
array_day2 = np.array([4, 0, 6, 5, 11, 14, 12, 14, 5, 16])

#B.
zero_array = np.zeros((10, 2))

#C. 
# one way
for A in range(0, len(array_day2)):
    checksquare = array_day2[A]**2
    if checksquare < 100:
        zero_array[A] = [array_day2[A], array_day2[A]**2]

# another way
for A in range(len(array_day2)):
    if array_day2[A]**2 < 100:
        zero_array[A] = [array_day2[A], array_day2[A]**2]
        

# a third way
for A, val in enumerate(array_day2):
    if val**2 < 100:
        zero_array[A] = [val, val**2]
        
#D.
print(zero_array)
# Out:
# [[ 4. 16.]
#  [ 0.  0.]
#  [ 6. 36.]
#  [ 5. 25.]
#  [ 0.  0.]
#  [ 0.  0.]
#  [ 0.  0.]
#  [ 0.  0.]
#  [ 5. 25.]
#  [ 0.  0.]]

# %% [markdown]
# #### Exercise 2
#
#    A. Write a function that takes an array of numbers and spits out a *damped sine curve*. This is a sine curve that slowly dies out. Here is the equation:
#
# $$ f(x) = a \exp{-x}*sin(b*x) $$
#
# where $a$ determines the max height of the curve and $b$ is the frequency of the sine curve.
#
# &nbsp;
#
#    B. Call the function a few different times for different values of `a` and `b`, feeding in an array of `x` from 0 to 10 each time.
#
#    C. Plot each version, making sure they have different colors and/or linestyles and include a legend. Btw, the documentation for customizations is here:
#
#     https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
#
#     https://matplotlib.org/gallery/color/named_colors.html
#
#
# If you have multiple lines with plt.plot(), Python will plot all of them together, unless you write plt.show() after each one. I want these all on one plot.

# %%
# your solutions here

def damp(x, a, b):
    ans = a*np.exp(-x)*np.sin(b*x)
    return ans

x = np.linspace(0, 10, 100)
curve1 = damp(x, 3, 1)
curve2 = damp(x, 2, 1)
curve3 = damp(x, 1, -3)

fig = plt.figure()


plt.plot(x, curve1, '--g', label=r'$a=3, b=1$')
plt.plot(x, curve2, '-b', label=r'$a=2, b=1$')

a3, b3 = 1, -3
plt.plot(x, curve3, ':r', label=r'$a=%.1f, b=%.1f$' %(a3, b3))

plt.xlabel('x', fontsize=16)

plt.ylabel('y', fontsize=16)

plt.title('gauss')

plt.tick_params(axis='both', which='both', direction='in', bottom=True, top=True, left=True, right=True)

plt.legend()

# %% [markdown]
# ### Day 3
# We are going to use OpenCV (`cv2`) just like we did in today's lesson to load an image into an array, then take a lineout. Then we can do some fitting with that data!

# %% [markdown]
# #### Exercise 1
#
#    A. Upload the file "preshot_image.jpg" to the "Files" tab (just as we did in class). Then load it into an array using `cv2.imread` and plot it with `plt.imshow`. Pick a colormap from  [these options](https://matplotlib.org/stable/tutorials/colors/colormaps.html). Scroll down to the pictures of colorbars and use the name beside the one you like.
#
#    B. Crop and plot a section of the image where there are only vertical lines (capture about 5-6 of these lines in your crop) and none of the big shadowy shapes.
#
#    C. Take a lineout of one row of your cropped image and plot it. Label your axes and give the plot a title.
#
# &nbsp;
#
# Hint: if you attempt to call a function from a library or package that hasn't been imported, you will get an error.

# %%
# your solutions here

# A
img = cv2.imread('preshot_image.jpg',0) #the zero tells it to load in grayscale
plt.imshow(img, cmap="inferno")
plt.show()

# B
img_crop = img[500:1500,2500:3000]
plt.imshow(img_crop, cmap="inferno")
plt.colorbar()
plt.show()

# C
lineout = img_crop[400,:]
plt.plot(lineout)
plt.xlabel("index")
plt.ylabel("pixel value")
plt.title('lineout of interference fringes')
plt.show()

# %% [markdown]
# #### Exercise 2
#
# A. Define a function that is a sine with some parameters to scale/translate the function:
#
# $$ f(x) = A\cdot sin(Bx - C) + D $$
#
# *Hint:* It is important to put the $x$ parameter first in your definition so that the next part works.
#
# &nbsp;
#
# B. Use `opt.curvefit` to fit a curve to your data from your lineout in the previous exercise. For the x-values, use `np.arange` to generate a list of indices the size of your lineout array. Try to estimate your initial guess from the plot in exercise 1B. Print the best-fit parameters (the bfpars).
#
# C. Feed the bfpars from the fit back into your function with your array of x-values to get the fitted curve data. Plot this on top of your plot of the lineout data. Be sure to use different markers for the different plots, and type `plt.show` at the end to display both plots together!

# %%
# your solutions here

# A
def mod_sine(x, A, B, C, D):
  ans = A*np.sin(B*x - C)+ D
  return ans

# B
bfpars, covar = opt.curve_fit(mod_sine, np.arange(len(lineout)), lineout, p0=[100, 2*np.pi/100, 0, 60])
print("bfpars =", bfpars)

# C
fitted_data = mod_sine(np.arange(len(lineout)), bfpars[0], bfpars[1], bfpars[2], bfpars[3])
plt.plot(lineout, "ob", label="data")
plt.plot(fitted_data, "r", label="curvefit")
plt.legend()
plt.xlabel("Index")
plt.ylabel("pixel value")
plt.show()
# Out:
# bfpars = [51.10385864  0.07623751  2.29563953 72.55530764]

# %% [markdown]
# &nbsp;
#
# Congrats on finishing! What you've just completed is part of a real research problem! I am so proud of how much you've managed to learn in a few brief days! Don't forget to turn this completed notebook in to Hannah.
